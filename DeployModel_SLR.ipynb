# %%
#import pickle library
import pickle

# %%
#Load Model file and read binary to test 0 years exp. (To find Freshers Salary)
loaded_model = pickle.load(open("finalizedmodel_SLR.sav",'rb'))
result=loaded_model.predict([[0]])
# Out:
# C:\Users\mohan\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[26777.3913412]])
