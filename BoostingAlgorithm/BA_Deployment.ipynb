# %%
import pickle

# %%
loaded_model = pickle.load(open("finalizedmodel_BA.sav",'rb'))
result = loaded_model.predict([[5678.20,678.30,7686.50,1,0]])
# Out:
# C:\Users\mohan\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([57208.415])
